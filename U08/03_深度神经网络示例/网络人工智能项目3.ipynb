# %% [markdown]
# # 神经网络预测流量数据

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
np.set_printoptions(suppress=True)

# %% [markdown]
# ## 1. 载入数据

# %%
path = 'netflow.csv'
pd_data = pd.read_csv(path)
pd_data.head()
# Out:
#    Unnamed: 0                                Flow.ID      Source.IP  \
# 0           0    172.19.1.46-10.200.7.7-52422-3128-6    172.19.1.46
# 1           1    172.19.1.46-10.200.7.7-52422-3128-6     10.200.7.7
# 2           2   10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39
# 3           3   10.200.7.217-50.31.185.39-38848-80-6   50.31.185.39
# 4           4  192.168.72.43-10.200.7.7-55961-3128-6  192.168.72.43
#
#    Source.Port Destination.IP  Destination.Port  Protocol           Timestamp  \
# 0        52422     10.200.7.7              3128         6  26/04/201711:11:17
# 1         3128    172.19.1.46             52422         6  26/04/201711:11:17
# 2           80   10.200.7.217             38848         6  26/04/201711:11:17
# 3           80   10.200.7.217             38848         6  26/04/201711:11:17
# 4        55961     10.200.7.7              3128         6  26/04/201711:11:17
#
#    Flow.Duration  Total.Fwd.Packets  ...  Active.Std  Active.Max  Active.Min  \
# 0          45523                 22  ...         0.0           0           0
# 1              1                  2  ...         0.0           0           0
# 2              1                  3  ...         0.0           0           0
# 3            217                  1  ...         0.0           0           0
# 4          78068                  5  ...         0.0           0           0
#
#    Idle.Mean  Idle.Std  Idle.Max  Idle.Min   Label  L7Protocol  ProtocolName
# 0        0.0       0.0         0         0  BENIGN         131    HTTP_PROXY
# 1        0.0       0.0         0         0  BENIGN         131    HTTP_PROXY
# 2        0.0       0.0         0         0  BENIGN           7          HTTP
# 3        0.0       0.0         0         0  BENIGN           7          HTTP
# 4        0.0       0.0         0         0  BENIGN         131    HTTP_PROXY
#
# [5 rows x 88 columns]

# %%
pd_data.keys()
# Out:
# Index(['Unnamed: 0', 'Flow.ID', 'Source.IP', 'Source.Port', 'Destination.IP',
#        'Destination.Port', 'Protocol', 'Timestamp', 'Flow.Duration',
#        'Total.Fwd.Packets', 'Total.Backward.Packets',
#        'Total.Length.of.Fwd.Packets', 'Total.Length.of.Bwd.Packets',
#        'Fwd.Packet.Length.Max', 'Fwd.Packet.Length.Min',
#        'Fwd.Packet.Length.Mean', 'Fwd.Packet.Length.Std',
#        'Bwd.Packet.Length.Max', 'Bwd.Packet.Length.Min',
#        'Bwd.Packet.Length.Mean', 'Bwd.Packet.Length.Std', 'Flow.Bytes.s',
#        'Flow.Packets.s', 'Flow.IAT.Mean', 'Flow.IAT.Std', 'Flow.IAT.Max',
#        'Flow.IAT.Min', 'Fwd.IAT.Total', 'Fwd.IAT.Mean', 'Fwd.IAT.Std',
#        'Fwd.IAT.Max', 'Fwd.IAT.Min', 'Bwd.IAT.Total', 'Bwd.IAT.Mean',
#        'Bwd.IAT.Std', 'Bwd.IAT.Max', 'Bwd.IAT.Min', 'Fwd.PSH.Flags',
#        'Bwd.PSH.Flags', 'Fwd.URG.Flags', 'Bwd.URG.Flags', 'Fwd.Header.Length',
#        'Bwd.Header.Length', 'Fwd.Packets.s', 'Bwd.Packets.s',
#        'Min.Packet.Length', 'Max.Packet.Length', 'Packet.Length.Mean',
#        'Packet.Length.Std', 'Packet.Length.Variance', 'FIN.Flag.Count',
#        'SYN.Flag.Count', 'RST.Flag.Count', 'PSH.Flag.Count', 'ACK.Flag.Count',
#        'URG.Flag.Count', 'CWE.Flag.Count', 'ECE.Flag.Count', 'Down.Up.Ratio',
#        'Average.Packet.Size', 'Avg.Fwd.Segment.Size', 'Avg.Bwd.Segment.Size',
#        'Fwd.Header.Length.1', 'Fwd.Avg.Bytes.Bulk', 'Fwd.Avg.Packets.Bulk',
#        'Fwd.Avg.Bulk.Rate', 'Bwd.Avg.Bytes.Bulk', 'Bwd.Avg.Packets.Bulk',
#        'Bwd.Avg.Bulk.Rate', 'Subflow.Fwd.Packets', 'Subflow.Fwd.Bytes',
#        'Subflow.Bwd.Packets', 'Subflow.Bwd.Bytes', 'Init_Win_bytes_forward',
#        'Init_Win_bytes_backward', 'act_data_pkt_fwd', 'min_seg_size_forward',
#        'Active.Mean', 'Active.Std', 'Active.Max', 'Active.Min', 'Idle.Mean',
#        'Idle.Std', 'Idle.Max', 'Idle.Min', 'Label', 'L7Protocol',
#        'ProtocolName'],
#       dtype='object')

# %% [markdown]
# ## 2 数据处理

# %%
drop_ids = ['Flow.Packets.s','Flow.Bytes.s','Flow.ID','Source.IP', 'Source.Port','Destination.IP','Destination.Port','Timestamp','Label','L7Protocol','ProtocolName']
target_fields = 'Flow.Packets.s'

# %%
Datas = pd_data.drop(drop_ids, axis=1)
D_mean = Datas.mean(axis=0)
D_std = Datas.std(axis=0)
Datas = (Datas - D_mean) / D_std
Datas = Datas.fillna(0)
Ori_Labels = pd_data.loc[:,target_fields]
result_mean = Ori_Labels.mean()
result_std = Ori_Labels.std()
Labels = (Ori_Labels - result_mean) / result_std
train_features, train_targets = Datas.iloc[:-2000], Labels.iloc[:-2000]
val_features, val_targets = Datas.iloc[-2000:-1000], Labels.iloc[-2000:-1000]
test_features, test_targets = Datas.iloc[-1000:], Ori_Labels.iloc[-1000:]
print(train_features.shape, train_targets.shape)
print(val_features.shape, val_targets.shape)
print(test_features.shape, test_targets.shape)
# Out:
# (98000, 77) (98000,)
# (1000, 77) (1000,)
# (1000, 77) (1000,)

# %% [markdown]
# ## 3 编写神经网络

# %%
def create_model():
    INPUT = tf.keras.Input((77,))
    X = tf.keras.layers.Dense(8, activation='sigmoid')(INPUT)
    X = tf.keras.layers.Dense(8, activation='sigmoid')(X)
    Y = tf.keras.layers.Dense(1, activation=None)(X)
    model = tf.keras.Model(inputs=INPUT, outputs=Y)
    
    model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.07),
                  loss=tf.keras.losses.MeanAbsoluteError())
    
    return model

model = create_model()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 77)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 8)              │           624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 705 (2.75 KB)
#  Trainable params: 705 (2.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 4. 开始训练

# %%
batch_size = 256
epochs = 100

log = model.fit(train_features,
                train_targets,
                batch_size=batch_size,
                epochs=epochs,
                validation_data=[val_features, val_targets])
# Out:
# Epoch 1/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3415 - val_loss: 0.1329
# Epoch 2/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3271 - val_loss: 0.1186
# Epoch 3/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3139 - val_loss: 0.1527
# Epoch 4/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2904 - val_loss: 0.1094
# Epoch 5/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2659 - val_loss: 0.1817
# Epoch 6/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2058 - val_loss: 0.1112
# Epoch 7/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1267 - val_loss: 0.0878
# Epoch 8/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1061 - val_loss: 0.1050
# Epoch 9/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0940 - val_loss: 0.1109
# Epoch 10/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0833 - val_loss: 0.0541
# Epoch 11/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0768 - val_loss: 0.0971
# Epoch 12/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0702 - val_loss: 0.0477
# Epoch 13/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0663 - val_loss: 0.0850
# Epoch 14/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0639 - val_loss: 0.0502
# Epoch 15/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0612 - val_loss: 0.0759
# Epoch 16/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0596 - val_loss: 0.0437
# Epoch 17/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0574 - val_loss: 0.0725
# Epoch 18/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0572 - val_loss: 0.0433
# Epoch 19/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0559 - val_loss: 0.0669
# Epoch 20/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0555 - val_loss: 0.0424
# Epoch 21/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0547 - val_loss: 0.0736
# Epoch 22/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0530 - val_loss: 0.0412
# Epoch 23/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0528 - val_loss: 0.0661
# Epoch 24/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0522 - val_loss: 0.0462
# Epoch 25/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0505 - val_loss: 0.0644
# Epoch 26/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0507 - val_loss: 0.0449
# Epoch 27/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0493 - val_loss: 0.0467
# Epoch 28/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0487 - val_loss: 0.0399
# Epoch 29/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0482 - val_loss: 0.0473
# Epoch 30/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0472 - val_loss: 0.0476
# Epoch 31/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0473 - val_loss: 0.0565
# Epoch 32/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0467 - val_loss: 0.0348
# Epoch 33/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0454 - val_loss: 0.0561
# Epoch 34/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0449 - val_loss: 0.0449
# Epoch 35/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0443 - val_loss: 0.0543
# Epoch 36/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0442 - val_loss: 0.0386
# Epoch 37/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0444 - val_loss: 0.0546
# Epoch 38/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0437 - val_loss: 0.0371
# Epoch 39/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0431 - val_loss: 0.0533
# Epoch 40/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0436 - val_loss: 0.0362
# Epoch 41/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0433 - val_loss: 0.0476
# Epoch 42/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0428 - val_loss: 0.0335
# Epoch 43/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0428 - val_loss: 0.0580
# Epoch 44/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0423 - val_loss: 0.0341
# Epoch 45/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0425 - val_loss: 0.0552
# Epoch 46/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0424 - val_loss: 0.0347
# Epoch 47/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0423 - val_loss: 0.0527
# Epoch 48/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0419 - val_loss: 0.0328
# Epoch 49/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0415 - val_loss: 0.0518
# Epoch 50/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0416 - val_loss: 0.0298
# Epoch 51/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0416 - val_loss: 0.0489
# Epoch 52/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0418 - val_loss: 0.0347
# Epoch 53/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0417 - val_loss: 0.0537
# Epoch 54/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0419 - val_loss: 0.0326
# Epoch 55/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0415 - val_loss: 0.0526
# Epoch 56/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0411 - val_loss: 0.0363
# Epoch 57/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0410 - val_loss: 0.0542
# Epoch 58/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0409 - val_loss: 0.0331
# Epoch 59/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0409 - val_loss: 0.0512
# Epoch 60/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0406 - val_loss: 0.0540
# Epoch 61/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0410 - val_loss: 0.0321
# Epoch 62/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0408 - val_loss: 0.0529
# Epoch 63/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0406 - val_loss: 0.0377
# Epoch 64/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0411 - val_loss: 0.0551
# Epoch 65/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0406 - val_loss: 0.0284
# Epoch 66/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0406 - val_loss: 0.0527
# Epoch 67/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0403 - val_loss: 0.0341
# Epoch 68/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0405 - val_loss: 0.0521
# Epoch 69/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0407 - val_loss: 0.0313
# Epoch 70/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0406 - val_loss: 0.0515
# Epoch 71/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0397 - val_loss: 0.0354
# Epoch 72/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0401 - val_loss: 0.0506
# Epoch 73/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0399 - val_loss: 0.0325
# Epoch 74/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0397 - val_loss: 0.0535
# Epoch 75/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0400 - val_loss: 0.0301
# Epoch 76/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0398 - val_loss: 0.0535
# Epoch 77/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0399 - val_loss: 0.0293
# Epoch 78/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0399 - val_loss: 0.0484
# Epoch 79/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0398 - val_loss: 0.0254
# Epoch 80/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0396 - val_loss: 0.0522
# Epoch 81/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0399 - val_loss: 0.0271
# Epoch 82/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0398 - val_loss: 0.0503
# Epoch 83/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0399 - val_loss: 0.0295
# Epoch 84/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0387 - val_loss: 0.0525
# Epoch 85/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0394 - val_loss: 0.0246
# Epoch 86/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0393 - val_loss: 0.0505
# Epoch 87/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0395 - val_loss: 0.0305
# Epoch 88/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0395 - val_loss: 0.0457
# Epoch 89/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0389 - val_loss: 0.0338
# Epoch 90/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0392 - val_loss: 0.0493
# Epoch 91/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0395 - val_loss: 0.0262
# Epoch 92/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0394 - val_loss: 0.0486
# Epoch 93/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0393 - val_loss: 0.0308
# Epoch 94/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0390 - val_loss: 0.0503
# Epoch 95/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0392 - val_loss: 0.0327
# Epoch 96/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0394 - val_loss: 0.0491
# Epoch 97/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0392 - val_loss: 0.0234
# Epoch 98/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0386 - val_loss: 0.0512
# Epoch 99/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0390 - val_loss: 0.0244
# Epoch 100/100
# 383/383 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0391 - val_loss: 0.0489

# %% [markdown]
# ## 5. 可视化训练过程与结果

# %%
plt.plot(log.history['loss'],label='Training Loss')
plt.plot(log.history['val_loss'], label='Validation Loss')
plt.legend()

# %%
rand_num = np.random.choice(900)
#rand_num=765
print(rand_num)
results = model.predict(test_features[rand_num:rand_num+100]).squeeze()
results = results * result_std + result_mean
results = np.where(results<0, 0, results)
labels = test_targets[rand_num:rand_num+100].to_numpy()

plt_x = np.linspace(0,100,100)
plt.subplot(121)
plt.plot(plt_x, labels, 'g')
plt.subplot(122)
plt.plot(plt_x, results, 'r')
plt.show()
# Out:
# 779
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
plt.plot(labels,label='label')
plt.plot(results, label='AI')
plt.legend()
